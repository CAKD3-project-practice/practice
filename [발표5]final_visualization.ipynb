# %%
import pandas as pd
df = pd.read_csv('dataset/final_result.csv')
df
# Out:
#            date  avgrhm  avgts  maxta  sumrn        pct  day  olympic
# 0    2010-07-01     3.0    1.0    0.0   -9.0  -2.618614    1        0
# 1    2010-07-02    10.0   -1.0   -2.0   -1.0 -13.256075    1        0
# 2    2010-07-03     8.0    0.0    0.0  -13.0 -17.423666    0        0
# 3    2010-07-04     6.0    0.0   -1.0  -16.0   3.782170    0        0
# 4    2010-07-05     1.0    2.0    2.0  -16.0  -0.742939    1        0
# ..          ...     ...    ...    ...    ...        ...  ...      ...
# 677  2020-08-27     6.0   -1.0    0.0    6.0  10.029647    1        0
# 678  2020-08-28     8.0    1.0    0.0    9.0  10.956910    1        0
# 679  2020-08-29    10.0    0.0    0.0    9.0  -5.672963    0        0
# 680  2020-08-30     8.0    1.0    0.0    6.0  -7.447197    0        0
# 681  2020-08-31     4.0   -1.0   -2.0   -1.0   7.066548    1        0
#
# [682 rows x 8 columns]

# %%
import pandas as pd
df['date'] = pd.to_datetime(df['date'])

# %%
df2 = df.corr()
df2
# Out:
#            avgrhm     avgts     maxta     sumrn       pct       day   olympic
# avgrhm   1.000000 -0.552979 -0.541246  0.651349 -0.204373 -0.000370 -0.237291
# avgts   -0.552979  1.000000  0.945074 -0.433738  0.426574 -0.001947  0.362062
# maxta   -0.541246  0.945074  1.000000 -0.455402  0.377025  0.004194  0.291320
# sumrn    0.651349 -0.433738 -0.455402  1.000000 -0.055489 -0.026570 -0.139657
# pct     -0.204373  0.426574  0.377025 -0.055489  1.000000  0.522925  0.187690
# day     -0.000370 -0.001947  0.004194 -0.026570  0.522925  1.000000 -0.024430
# olympic -0.237291  0.362062  0.291320 -0.139657  0.187690 -0.024430  1.000000

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df2,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
sns.pairplot(data=df[['avgrhm','avgts','maxta','sumrn','pct']])

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='pct',data=df,color='midnightblue')
# Out:
# <AxesSubplot:xlabel='date', ylabel='pct'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
sns.barplot(x='date',y='pct',data=df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='pct'>

# %%
sns.regplot(x='pct',y='maxta',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='maxta'>

# %%
sns.regplot(x='pct',y='avgts',data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='avgts'>

# %%
sns.regplot(x='pct',y='maxta',data=df,color='red')
sns.regplot(x='pct',y='avgts',data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='avgts'>

# %%
sns.regplot(x='pct',y='avgrhm',data=df,color='midnightblue')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='avgrhm'>

# %%
sns.regplot(x='pct',y='sumrn',data=df,color='midnightblue')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='sumrn'>

# %%
sns.regplot(x='pct',y='avgrhm',data=df,color='red')
sns.regplot(x='pct',y='sumrn',data=df,color='midnightblue')
# Out:
# <AxesSubplot:xlabel='pct', ylabel='sumrn'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
sns.set(rc={'figure.figsize':(8,6)})
sns.regplot(x='avgrhm',y='sumrn',data=df,color='midnightblue')
# Out:
# <AxesSubplot:xlabel='avgrhm', ylabel='sumrn'>

# %%
sns.scatterplot(x='maxta',y='avgrhm',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='maxta', ylabel='avgrhm'>

# %%
sns.barplot(x='day',y='pct',palette='Reds',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='pct'>

# %%
sns.barplot(x='avgrhm',y='pct',hue='day',data=df,palette='Reds',ci=None)
# Out:
# <AxesSubplot:xlabel='avgrhm', ylabel='pct'>

# %%
sns.barplot(x='maxta',y='pct',hue='day',palette='Reds',data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='maxta', ylabel='pct'>

# %%
sns.barplot(x='olympic',y='pct',palette='pastel',data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='olympic', ylabel='pct'>

# %%
df['olympic'].value_counts()
# Out:
# 0    644
# 1     38
# Name: olympic, dtype: int64
